# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline
import nltk
import math
import numpy as np

# %%
data = pd.read_csv('/Users/mac/Dropbox/Git/dorahacktradegeneration/data/BTCUSD_all.csv')
data = data[::-1]
data['Timestamp'] = pd.to_datetime(data['Timestamp'],dayfirst=True)
data.index= data['Timestamp']
sentiment = pd.read_csv('/Users/mac/Dropbox/Git/dorahacktradegeneration/data/reddit_sentiment_clean_3.csv')
sentiment = sentiment.drop(sentiment.columns[0], axis=1)

# %%
plt.figure(figsize=(20,6))
plt.plot(data['Close'])

# %%
plt.figure(figsize=(20,6))
plt.plot(data['Volume'])

# %%
sentiment.head(10)
# Out:
#                                             Sentenec  Negative  Neutral  \
# 0  Why don't more women in the sex industry accep...       0.0    0.776
# 1                                      What the FEE?       0.0    1.000
# 2                     What did you do with your BCH?       0.0    1.000
# 3  Please contact these companies and ask them to...       0.0    0.667
# 4  To whom had played Dungeon defender, remember ...       0.0    0.703
# 5                    not $5,000 yet? needs more FOMO       0.0    1.000
# 6  Bitcoin/Ether New Highs | F2Pool Ditches Segwi...       0.0    1.000
# 7                    I borrowed $30000 from the bank       0.0    1.000
# 8                           GBTC IS OVER $9,000 !!!!       0.0    1.000
# 9  I was very excited when I picked the package a...       0.0    0.895
#
#    Positive  Compound         Timestamp  IndicatorPositive  IndicatorNegative  \
# 0     0.224    0.3818  01/09/2017 00:03                  1                  0
# ...
